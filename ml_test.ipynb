# %% [markdown]
# ## Theory
#
# ### Introduction
# The Naive Bayes classifier is a probabilistic machine learning algorithm based on Bayes' Theorem,
# used extensively for text classification tasks such as spam detection,
# sentiment analysis, and topic categorization.
# Its "naive" assumption is that features (words, in text classification)
# are conditionally independent given the class label.
# Despite this simplification, it performs well in many real-world scenarios,
# and in the case of banking data, the order of the words is unlikely to hold any information.
#
# ### Baye's Theorem
#
# The Formula is given as
#
# $P(H|E) = \frac{P(E|H)P(H)}{P(E)}$
#
# where:
# - $P(H∣E)$: Posterior probability of *Hypothesis*, given that the *Evidence* is true
# - $P(E∣H)$: Likelihood of *Evidence*, given that the *Hypothesis* is true
# - $P(H)$: Prior propability of the *Hypothesis*
# - $P(E)$: Prior propability that the *Evidence* is true
#
# In the banking file processing, the Hypothesis is to assume the row to be some *Category*,
# and the Evidences are the *Feature* vector X. The Propability of seing the Evidence is constant,
# for all of the Categoires, and thus, the formula can be used as
#
# $P(C|X) \propto P(X|C)P(C)$
#
# The classifier assumes each word's occurrence in a document is independent of others, simplifying computation:
#
# $P(X|C) = P(x_1|C) \cdot P(x_2|C) \cdot ... \cdot P(x_n|C)$
#
# ### Training
# Uses labeled data to estimate probabilities $P(X_i|C)$ and $P(C)$.
# Handling missing tokens (words not encountered during training)
# is a critical aspect of the Naive Bayes classifier to avoid issues like zero probabilities.
# If a token $x_i$ is not present in the training data for a particular class $C$,
# its likelihood $P(x_i|C) = 0$. Since Naive Bayes multiplies probabilities,
# a single zero can make the entire product $P(X|C) = 0$.
# To address this, Laplace Smoothing techniques is used,
# where 1 is added to each $P(x_i|C)$ to prevent zeros.
# The mathematical effect will be minimal for larger datasets,
# but it will make the model more robust for unseen data.
# The propabilites are computed in the log-format to prevent
# underflow erros, and transformed back to the normal format
# to give more meaningfull results.
#
# ### Advantages
# - Computationally efficient and simple to implement.
# - Performs well with small datasets and text data.
# - Robust to irrelevant features.
# ### Limitations
# - The independence assumption is often violated in real-world text data.
# - Struggles with complex decision boundaries compared to more advanced methods like deep learning.

# %% [markdown]
# ## Code

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import the model module from Backend

# %%
from backend.ml.model import NB

# %% [markdown]
# ## Get the Example Data

# %%
df_train = pd.read_csv('frontend/app_assets/your_banking_file1.csv')

df_train = df_train.fillna('N/A') # The model does not work with Nan values -> those must be filled or removed

df_train['Category'] = np.random.choice(['FOOD', 'HEALTH', 'OTHER'], df_train.shape[0]) # Fill Mock Categoires, since those are not already classified

display(df_train.head(5))
# Out:
#          Date           Receiver  Amount SomeRandomColumn Category
# 0  2022-07-31       VR-YHTYMÄ OY  -49.90              N/A    OTHER
# 1  2022-07-27       VR-YHTYMÄ OY  -27.00              N/A     FOOD
# 2  2022-07-27  STOCKMANN TAPIOLA  -53.40              N/A    OTHER
# 3  2022-07-25         BESTSELLER  -79.99              N/A     FOOD
# 4  2022-07-25   PRISMA ISO OMENA  -34.66              N/A    OTHER

# %% [markdown]
# ## Init the model and Fit it

# %%
model = NB()

model.fit(str_features=df_train[['Receiver']].to_numpy(), # The model supports multiple columns for String, and Float inputs, and excpects those to be 2D Numpy Arryas
          float_features=df_train[['Amount']].to_numpy(), 
          y=df_train['Category'].to_numpy()
          )

# %% [markdown]
# ## Display model Prior propabilites for each target
# ### $P(C)$ means the overall propability of seing each Class

# %%
for key, value in model.get_priors().items(): # This is the overall propability of seing each Category in the dataset 

    print(f'Category: {key: >6}, Propability: {value*100:.2f}%')
# Out:
# Category:  OTHER, Propability: 46.15%
# Category:   FOOD, Propability: 28.21%
# Category: HEALTH, Propability: 25.64%

# %% [markdown]
# ## Display the Likelihoods of each Token, given the Category
# ### $P(X_i|C)$ means what is the propability of seing the Feature, if I assume I know the Class

# %%
for key, value in model.get_likelihoods().items(): # What is the Likelihood to see some Token, given that the cateogry is known
    print(f'Category: {key}:')

    for key2, value2 in value.items():
        print(f'\tToken: {key2:>16}, Likelihood: {value2*100:.2f}%')
# Out:
# Category: OTHER:
# 	Token: negativecashflow, Likelihood: 100.00%
# 	Token:      smallamount, Likelihood: 68.42%
# 	Token:     mediumamount, Likelihood: 36.84%
# 	Token:               oy, Likelihood: 26.32%
# 	Token:            omena, Likelihood: 15.79%
# 	Token:               vr, Likelihood: 15.79%
# 	Token:              iso, Likelihood: 15.79%
# 	Token:           yhtymä, Likelihood: 15.79%
# 	Token:              oyj, Likelihood: 15.79%
# 	Token:               at, Likelihood: 10.53%
# 	Token:        kauhajoki, Likelihood: 10.53%
# 	Token:           prisma, Likelihood: 10.53%
# 	Token:       citymarket, Likelihood: 10.53%
# 	Token:               ya, Likelihood: 10.53%
# 	Token:              seo, Likelihood: 10.53%
# 	Token:              vfi, Likelihood: 10.53%
# 	Token:                k, Likelihood: 10.53%
# 	Token:              dna, Likelihood: 10.53%
# 	Token:        markkinak, Likelihood: 10.53%
# 	Token:             tori, Likelihood: 10.53%
# 	Token:          finland, Likelihood: 10.53%
# 	Token:      ca778475780, Likelihood: 10.53%
# 	Token:              tmk, Likelihood: 10.53%
# 	Token:            adobe, Likelihood: 10.53%
# 	Token:          station, Likelihood: 10.53%
# 	Token:           grilli, Likelihood: 10.53%
# 	Token:          mobiili, Likelihood: 10.53%
# 	Token:            group, Likelihood: 10.53%
# 	Token:        stockmann, Likelihood: 10.53%
# 	Token:              hsl, Likelihood: 10.53%
# 	Token:             stop, Likelihood: 10.53%
# 	Token:            jaala, Likelihood: 10.53%
# 	Token:         nintendo, Likelihood: 10.53%
# 	Token:          tapiola, Likelihood: 10.53%
# 	Token:              n/a, Likelihood: 10.53%
# 	Token:            aalto, Likelihood: 10.53%
# 	Token:         paytrail, Likelihood: 10.53%
# 	Token:        tietotekn, Likelihood: 10.53%
# 	Token:             plan, Likelihood: 10.53%
# 	Token:         susannan, Likelihood: 10.53%
# 	Token:          compass, Likelihood: 10.53%
# 	Token:               ja, Likelihood: 10.53%
# 	Token:        photogphy, Likelihood: 10.53%
# 	Token:           avecra, Likelihood: 10.53%
# 	Token:                b, Likelihood: 5.26%
# 	Token:          netflix, Likelihood: 5.26%
# 	Token:          kabacka, Likelihood: 5.26%
# 	Token:      squarespace, Likelihood: 5.26%
# 	Token:           vierum, Likelihood: 5.26%
# 	Token:            smoke, Likelihood: 5.26%
# 	Token:            neste, Likelihood: 5.26%
# 	Token:              ruo, Likelihood: 5.26%
# 	Token:      supermarket, Likelihood: 5.26%
# 	Token:                r, Likelihood: 5.26%
# 	Token:       bestseller, Likelihood: 5.26%
# 	Token:             uusi, Likelihood: 5.26%
# 	Token:          galaxie, Likelihood: 5.26%
# 	Token:         helsinki, Likelihood: 5.26%
# 	Token:             holy, Likelihood: 5.26%
# 	Token:          aaltoyo, Likelihood: 5.26%
# 	Token:           center, Likelihood: 5.26%
# 	Token:                v, Likelihood: 5.26%
# 	Token:            alepa, Likelihood: 5.26%
# 	Token:      metrokeskus, Likelihood: 5.26%
# 	Token:              inc, Likelihood: 5.26%
# 	Token:         otaniemi, Likelihood: 5.26%
# 	Token:    international, Likelihood: 5.26%
# 	Token:            waino, Likelihood: 5.26%
# 	Token:                o, Likelihood: 5.26%
# 	Token:           klarna, Likelihood: 5.26%
# 	Token:               se, Likelihood: 5.26%
# 	Token:                &, Likelihood: 5.26%
# 	Token:               ab, Likelihood: 5.26%
# 	Token:        kotipizza, Likelihood: 5.26%
# 	Token:          heinola, Likelihood: 5.26%
# Category: FOOD:
# 	Token: negativecashflow, Likelihood: 100.00%
# 	Token:     mediumamount, Likelihood: 58.33%
# 	Token:      smallamount, Likelihood: 50.00%
# 	Token:                k, Likelihood: 25.00%
# 	Token:               vr, Likelihood: 25.00%
# 	Token:           yhtymä, Likelihood: 25.00%
# 	Token:               oy, Likelihood: 25.00%
# 	Token:                b, Likelihood: 16.67%
# 	Token:          netflix, Likelihood: 16.67%
# 	Token:          kabacka, Likelihood: 16.67%
# 	Token:       citymarket, Likelihood: 16.67%
# 	Token:            smoke, Likelihood: 16.67%
# 	Token:              ruo, Likelihood: 16.67%
# 	Token:      supermarket, Likelihood: 16.67%
# 	Token:       bestseller, Likelihood: 16.67%
# 	Token:             uusi, Likelihood: 16.67%
# 	Token:          galaxie, Likelihood: 16.67%
# 	Token:         helsinki, Likelihood: 16.67%
# 	Token:             holy, Likelihood: 16.67%
# 	Token:              iso, Likelihood: 16.67%
# 	Token:           center, Likelihood: 16.67%
# 	Token:                v, Likelihood: 16.67%
# 	Token:          tapiola, Likelihood: 16.67%
# 	Token:            alepa, Likelihood: 16.67%
# 	Token:         otaniemi, Likelihood: 16.67%
# 	Token:    international, Likelihood: 16.67%
# 	Token:            waino, Likelihood: 16.67%
# 	Token:                o, Likelihood: 16.67%
# 	Token:               se, Likelihood: 16.67%
# 	Token:                &, Likelihood: 16.67%
# 	Token:        kotipizza, Likelihood: 16.67%
# 	Token:               at, Likelihood: 8.33%
# 	Token:        kauhajoki, Likelihood: 8.33%
# 	Token:           prisma, Likelihood: 8.33%
# 	Token:            omena, Likelihood: 8.33%
# 	Token:               ya, Likelihood: 8.33%
# 	Token:              seo, Likelihood: 8.33%
# 	Token:      squarespace, Likelihood: 8.33%
# 	Token:              vfi, Likelihood: 8.33%
# 	Token:           vierum, Likelihood: 8.33%
# 	Token:              dna, Likelihood: 8.33%
# 	Token:        markkinak, Likelihood: 8.33%
# 	Token:             tori, Likelihood: 8.33%
# 	Token:          finland, Likelihood: 8.33%
# 	Token:            neste, Likelihood: 8.33%
# 	Token:      ca778475780, Likelihood: 8.33%
# 	Token:              tmk, Likelihood: 8.33%
# 	Token:            adobe, Likelihood: 8.33%
# 	Token:                r, Likelihood: 8.33%
# 	Token:          station, Likelihood: 8.33%
# 	Token:           grilli, Likelihood: 8.33%
# 	Token:          mobiili, Likelihood: 8.33%
# 	Token:            group, Likelihood: 8.33%
# 	Token:        stockmann, Likelihood: 8.33%
# 	Token:          aaltoyo, Likelihood: 8.33%
# 	Token:              hsl, Likelihood: 8.33%
# 	Token:             stop, Likelihood: 8.33%
# 	Token:            jaala, Likelihood: 8.33%
# 	Token:         nintendo, Likelihood: 8.33%
# 	Token:              n/a, Likelihood: 8.33%
# 	Token:      metrokeskus, Likelihood: 8.33%
# 	Token:              inc, Likelihood: 8.33%
# 	Token:            aalto, Likelihood: 8.33%
# 	Token:         paytrail, Likelihood: 8.33%
# 	Token:        tietotekn, Likelihood: 8.33%
# 	Token:             plan, Likelihood: 8.33%
# 	Token:           klarna, Likelihood: 8.33%
# 	Token:         susannan, Likelihood: 8.33%
# 	Token:               ab, Likelihood: 8.33%
# 	Token:          compass, Likelihood: 8.33%
# 	Token:               ja, Likelihood: 8.33%
# 	Token:        photogphy, Likelihood: 8.33%
# 	Token:          heinola, Likelihood: 8.33%
# 	Token:           avecra, Likelihood: 8.33%
# 	Token:              oyj, Likelihood: 8.33%
# Category: HEALTH:
# 	Token: negativecashflow, Likelihood: 100.00%
# 	Token:      smallamount, Likelihood: 72.73%
# 	Token:     mediumamount, Likelihood: 36.36%
# 	Token:             uusi, Likelihood: 36.36%
# 	Token:            alepa, Likelihood: 36.36%
# 	Token:         otaniemi, Likelihood: 36.36%
# 	Token:            omena, Likelihood: 18.18%
# 	Token:               ya, Likelihood: 18.18%
# 	Token:      squarespace, Likelihood: 18.18%
# 	Token:           vierum, Likelihood: 18.18%
# 	Token:          finland, Likelihood: 18.18%
# 	Token:            neste, Likelihood: 18.18%
# 	Token:                r, Likelihood: 18.18%
# 	Token:            group, Likelihood: 18.18%
# 	Token:          aaltoyo, Likelihood: 18.18%
# 	Token:              iso, Likelihood: 18.18%
# 	Token:      metrokeskus, Likelihood: 18.18%
# 	Token:              inc, Likelihood: 18.18%
# 	Token:               oy, Likelihood: 18.18%
# 	Token:         paytrail, Likelihood: 18.18%
# 	Token:           klarna, Likelihood: 18.18%
# 	Token:               ab, Likelihood: 18.18%
# 	Token:          compass, Likelihood: 18.18%
# 	Token:          heinola, Likelihood: 18.18%
# 	Token:              oyj, Likelihood: 18.18%
# 	Token:               at, Likelihood: 9.09%
# 	Token:        kauhajoki, Likelihood: 9.09%
# 	Token:                b, Likelihood: 9.09%
# 	Token:          netflix, Likelihood: 9.09%
# 	Token:           prisma, Likelihood: 9.09%
# 	Token:          kabacka, Likelihood: 9.09%
# 	Token:       citymarket, Likelihood: 9.09%
# 	Token:              seo, Likelihood: 9.09%
# 	Token:              vfi, Likelihood: 9.09%
# 	Token:                k, Likelihood: 9.09%
# 	Token:              dna, Likelihood: 9.09%
# 	Token:        markkinak, Likelihood: 9.09%
# 	Token:             tori, Likelihood: 9.09%
# 	Token:            smoke, Likelihood: 9.09%
# 	Token:               vr, Likelihood: 9.09%
# 	Token:      ca778475780, Likelihood: 9.09%
# 	Token:              ruo, Likelihood: 9.09%
# 	Token:              tmk, Likelihood: 9.09%
# 	Token:            adobe, Likelihood: 9.09%
# 	Token:      supermarket, Likelihood: 9.09%
# 	Token:          station, Likelihood: 9.09%
# 	Token:       bestseller, Likelihood: 9.09%
# 	Token:           grilli, Likelihood: 9.09%
# 	Token:          mobiili, Likelihood: 9.09%
# 	Token:          galaxie, Likelihood: 9.09%
# 	Token:         helsinki, Likelihood: 9.09%
# 	Token:             holy, Likelihood: 9.09%
# 	Token:        stockmann, Likelihood: 9.09%
# 	Token:              hsl, Likelihood: 9.09%
# 	Token:           center, Likelihood: 9.09%
# 	Token:             stop, Likelihood: 9.09%
# 	Token:                v, Likelihood: 9.09%
# 	Token:           yhtymä, Likelihood: 9.09%
# 	Token:            jaala, Likelihood: 9.09%
# 	Token:         nintendo, Likelihood: 9.09%
# 	Token:          tapiola, Likelihood: 9.09%
# 	Token:              n/a, Likelihood: 9.09%
# 	Token:    international, Likelihood: 9.09%
# 	Token:            waino, Likelihood: 9.09%
# 	Token:            aalto, Likelihood: 9.09%
# 	Token:                o, Likelihood: 9.09%
# 	Token:        tietotekn, Likelihood: 9.09%
# 	Token:             plan, Likelihood: 9.09%
# 	Token:               se, Likelihood: 9.09%
# 	Token:                &, Likelihood: 9.09%
# 	Token:         susannan, Likelihood: 9.09%
# 	Token:        kotipizza, Likelihood: 9.09%
# 	Token:               ja, Likelihood: 9.09%
# 	Token:        photogphy, Likelihood: 9.09%
# 	Token:           avecra, Likelihood: 9.09%

# %% [markdown]
# ## Predict with the Model
# ### The Predictions are the Posterior propabilites $P(C|X) \propto$ in Descending order

# %%
preds = model.predict(str_features=np.array([['K-Supermaket Somewhere']]), # The pred are also 2D Numpy arrays, and can have multiple rows for batch prediction
                      float_features=np.array([[-45.45]])
                      )

display(preds) # The preds is a list of dicts, where each elelemnt is one row, and in this case, there is only one row
# Out:
# [{'FOOD': np.float64(0.04113247863247864),
#   'OTHER': np.float64(0.017898998508416787),
#   'HEALTH': np.float64(0.00847637211273575)}]

# %%
first_row_predictions = preds[0]
for key, value  in first_row_predictions.items(): # Each dict is The Posterrior Propability of each possible Category in Descending order 

    print(f'Category: {key: >6}, Posterrior: {value*100:.2f}%')
# Out:
# Category:   FOOD, Posterrior: 4.11%
# Category:  OTHER, Posterrior: 1.79%
# Category: HEALTH, Posterrior: 0.85%
